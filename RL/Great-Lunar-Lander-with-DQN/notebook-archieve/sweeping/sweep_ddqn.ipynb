# %% [markdown]
# ## Google Colab Setup
#
# Skip this section if running locally

# %%
# !git clone https://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@github.com/kiritowu/Great-Lunar-Lander.git
# %cd Great-Lunar-Lander
# Out:
# Cloning into 'Great-Lunar-Lander'...
# remote: Enumerating objects: 425, done.
# remote: Counting objects: 100% (425/425), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 425 (delta 239), reused 305 (delta 127), pack-reused 0
# Receiving objects: 100% (425/425), 3.45 MiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (239/239), done.
# /content/Great-Lunar-Lander

# %%
# %%capture
# !pip install Box2D
# !pip install box2d
# !pip install box2d-py
# !pip install gym[all]
# !pip install gym[Box_2D]
# !pip install wandb

# %% [markdown]
# ## Setup

# %%
import gym

import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model

from utils import seed_everything, Experience, ReplayBuffer
from collections import deque
from model.ddqn import DoubleDQN as DDQN
# Out:
# 2022-02-07 00:50:51.159268: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/tiencheng/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-07 00:50:51.159324: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import wandb

wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tiencheng (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# ## Define Train Function

# %%
def train(config=None):
    with wandb.init(config=config):
        config = wandb.config
        env = gym.make("LunarLander-v2")
        model = DDQN(
            env,
            config.lr,
            config.gamma,
            config.epsilon,
            config.epsilon_decay,
            config.update_target_net_interval,
            log_wandb=True,
            tuning_condition=True,
        )
        model.train(config.episodes, mean_stopping=False)

# %% [markdown]
# ## Start the Run

# %%
sweep_id = "tctxqok8"
project_name = "DDQN-Tuning"
num_runs = 50

# %%
wandb.agent(sweep_id, train, count=num_runs, entity="onsen", project=project_name)
# Out:
# 400 response executing GraphQL.
# {"errors":[{"message":"Sweep onsen/DDQN-Tuning/tctxqok8 is not running","path":["createAgent"]}],"data":{"createAgent":null}}
# wandb: ERROR Error while calling W&B API: Sweep onsen/DDQN-Tuning/tctxqok8 is not running (<Response [400]>)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:102, in Retry.__call__(self, *args, **kwargs)
#     101 try:
# --> 102     result = self._call_fn(*args, **kwargs)
#     103     # Only print resolved attempts once every minute
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:147, in Api.execute(self, *args, **kwargs)
#     146 self.display_gorilla_error_if_found(res)
# --> 147 six.reraise(*sys.exc_info())
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/six.py:719, in reraise(tp, value, tb)
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:141, in Api.execute(self, *args, **kwargs)
#     140 try:
# --> 141     return self.client.execute(*args, **kwargs)
#     142 except requests.exceptions.HTTPError as err:
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/vendor/gql-0.2.0/gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/vendor/gql-0.2.0/gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      59 if not self.retries:
# ---> 60     return self.transport.execute(document, *args, **kwargs)
#      62 last_exception = None
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/vendor/gql-0.2.0/gql/transport/requests.py:39, in RequestsHTTPTransport.execute(self, document, variable_values, timeout)
#      38 request = requests.post(self.url, **post_args)
# ---> 39 request.raise_for_status()
#      41 result = request.json()
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/requests/models.py:960, in Response.raise_for_status(self)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.wandb.ai/graphql
#
# During handling of the above exception, another exception occurred:
#
# UsageError                                Traceback (most recent call last)
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/apis/normalize.py:24, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 try:
# ---> 24     return func(*args, **kwargs)
#      25 except requests.HTTPError as err:
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:1641, in Api.register_agent(self, host, sweep_id, project_name, entity)
#    1639     raise UsageError(body["errors"][0]["message"])
# -> 1641 response = self.gql(
#    1642     mutation,
#    1643     variable_values={
#    1644         "host": host,
#    1645         "entityName": entity,
#    1646         "projectName": project_name,
#    1647         "sweep": sweep_id,
#    1648     },
#    1649     check_retry_fn=no_retry_4xx,
#    1650 )
#    1651 return response["createAgent"]["agent"]
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:118, in Retry.__call__(self, *args, **kwargs)
#     116 except self._retryable_exceptions as e:
#     117     # if the secondary check fails, re-raise
# --> 118     if not check_retry_fn(e):
#     119         raise
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:1639, in Api.register_agent.<locals>.no_retry_4xx(e)
#    1638 body = json.loads(e.response.content)
# -> 1639 raise UsageError(body["errors"][0]["message"])
#
# UsageError: Sweep onsen/DDQN-Tuning/tctxqok8 is not running
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 wandb.agent(sweep_id, train, count=num_runs, entity="onsen", project=project_name)
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/wandb_agent.py:576, in agent(sweep_id, function, entity, project, count)
#     574 wandb_sdk.wandb_login._login(_silent=True)
#     575 if function:
# --> 576     return pyagent(sweep_id, function, entity, project, count)
#     577 in_jupyter = wandb.wandb_sdk.lib.ipython._get_python_type() != "python"
#     578 return run_agent(
#     579     sweep_id,
#     580     function=function,
#    (...)
#     584     count=count,
#     585 )
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/agents/pyagent.py:348, in pyagent(sweep_id, function, entity, project, count)
#     344     raise Exception("function paramter must be callable!")
#     345 agent = Agent(
#     346     sweep_id, function=function, entity=entity, project=project, count=count,
#     347 )
# --> 348 agent.run()
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/agents/pyagent.py:323, in Agent.run(self)
#     317 def run(self):
#     318     logger.info(
#     319         "Starting sweep agent: entity={}, project={}, count={}".format(
#     320             self._entity, self._project, self._count
#     321         )
#     322     )
# --> 323     self._setup()
#     324     # self._main_thread = threading.Thread(target=self._run_jobs_from_queue)
#     325     self._heartbeat_thread = threading.Thread(target=self._heartbeat)
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/agents/pyagent.py:140, in Agent._setup(self)
#     138 if sweep_id:
#     139     self._sweep_id = sweep_id
# --> 140 self._register()
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/agents/pyagent.py:117, in Agent._register(self)
#     115 def _register(self):
#     116     logger.debug("Agent._register()")
# --> 117     agent = self._api.register_agent(socket.gethostname(), sweep_id=self._sweep_id)
#     118     self._agent_id = agent["id"]
#     119     logger.debug("agent_id = {}".format(self._agent_id))
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/apis/internal.py:120, in Api.register_agent(self, *args, **kwargs)
#     119 def register_agent(self, *args, **kwargs):
# --> 120     return self.api.register_agent(*args, **kwargs)
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/apis/normalize.py:62, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      60     six.reraise(*sys.exc_info())
#      61 else:
# ---> 62     six.reraise(CommError, CommError(message, err), sys.exc_info()[2])
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/six.py:718, in reraise(tp, value, tb)
#     716         value = tp()
#     717     if value.__traceback__ is not tb:
# --> 718         raise value.with_traceback(tb)
#     719     raise value
#     720 finally:
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/apis/normalize.py:24, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      22 message = "Whoa, you found a bug."
#      23 try:
# ---> 24     return func(*args, **kwargs)
#      25 except requests.HTTPError as err:
#      26     raise CommError(err.response, err)
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:1641, in Api.register_agent(self, host, sweep_id, project_name, entity)
#    1638     body = json.loads(e.response.content)
#    1639     raise UsageError(body["errors"][0]["message"])
# -> 1641 response = self.gql(
#    1642     mutation,
#    1643     variable_values={
#    1644         "host": host,
#    1645         "entityName": entity,
#    1646         "projectName": project_name,
#    1647         "sweep": sweep_id,
#    1648     },
#    1649     check_retry_fn=no_retry_4xx,
#    1650 )
#    1651 return response["createAgent"]["agent"]
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:118, in Retry.__call__(self, *args, **kwargs)
#     115     return result
#     116 except self._retryable_exceptions as e:
#     117     # if the secondary check fails, re-raise
# --> 118     if not check_retry_fn(e):
#     119         raise
#     120     if (
#     121         datetime.datetime.now() - start_time >= retry_timedelta
#     122         or self._num_iter >= num_retries
#     123     ):
#
# File ~/GitHub/Great-Lunar-Lander/env/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:1639, in Api.register_agent.<locals>.no_retry_4xx(e)
#    1637     return True
#    1638 body = json.loads(e.response.content)
# -> 1639 raise UsageError(body["errors"][0]["message"])
#
# CommError: Sweep onsen/DDQN-Tuning/tctxqok8 is not running
