# %%
# !git clone https://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@github.com/kiritowu/Great-Lunar-Lander.git
# %cd Great-Lunar-Lander
# Out:
# Cloning into 'Great-Lunar-Lander'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 152 (delta 77), reused 107 (delta 38), pack-reused 0
# Receiving objects: 100% (152/152), 1.40 MiB | 8.70 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# /content/Great-Lunar-Lander

# %%
# !pip install Box2D
# !pip install box2d
# !pip install box2d-py
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 7.1 MB/s
# ...
#      |████████████████████████████████| 448 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 8.5 MB/s
# ...
#      |████████████████████████████████| 180 kB 73.1 MB/s
# ...
#      |████████████████████████████████| 142 kB 60.3 MB/s
# ...
#      |████████████████████████████████| 97 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.5 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=bd134e66b2ed9fc3a060a9a437764972334ecc55d9691e88b5e3d175ba8d3bda
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=0d731ce77885adab058603075f2e010d83af28c180459dd5a314f5a8345893c6
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
import gym
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from utils import seed_everything, Experience, ReplayBuffer
from model.sarsa import SARSA

# %%
import wandb
wandb.login()
wandb.init(
    entity="onsen",
    project="sarsa-lunar-lander"
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: kiritowu (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/onsen/sarsa-lunar-lander/runs/hhfnvhy9" target="_blank">likely-tree-6</a></strong> to <a href="https://wandb.ai/onsen/sarsa-lunar-lander" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/onsen/sarsa-lunar-lander/runs/hhfnvhy9?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# Set random seed to 42
seed_everything(42)

# %%
env = gym.make('LunarLander-v2')

# set seeds
env.seed(42)

# setting up params
lr = 0.001
epsilon = 1.0
epsilon_decay = 0.995
gamma = 0.99
training_episodes = 1000

# create new deep q-network instance
model = SARSA(env, lr, gamma, epsilon, epsilon_decay, log_wandb=True)
model.train(training_episodes, max_num_steps = 1000)
# Out:
# [000] Reward: -362.521 | Avg Reward: -362.521 | e: 0.995 | Episode Length:  109
# [001] Reward:  -75.289 | Avg Reward: -218.905 | e: 0.990 | Episode Length:   79
# [002] Reward: -273.729 | Avg Reward: -237.180 | e: 0.985 | Episode Length:   90
# [003] Reward: -101.017 | Avg Reward: -203.139 | e: 0.980 | Episode Length:   73
# [004] Reward: -165.096 | Avg Reward: -195.530 | e: 0.975 | Episode Length:   67
# [005] Reward:  -92.769 | Avg Reward: -178.403 | e: 0.970 | Episode Length:   80
# [006] Reward:  -99.582 | Avg Reward: -167.143 | e: 0.966 | Episode Length:   86
# [007] Reward: -283.434 | Avg Reward: -181.679 | e: 0.961 | Episode Length:   84
# [008] Reward:  -96.772 | Avg Reward: -172.245 | e: 0.956 | Episode Length:   84
# [009] Reward: -113.977 | Avg Reward: -166.418 | e: 0.951 | Episode Length:   91
# [010] Reward: -223.862 | Avg Reward: -171.641 | e: 0.946 | Episode Length:   78
# [011] Reward:  -95.167 | Avg Reward: -165.268 | e: 0.942 | Episode Length:   68
# ...

# %%
model.save("saved-models/sarsa/model_run2.h5")
